# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.5.5

# %%
net=cv2.dnn.readNet("dnn_model/yolov4-tiny.weights","dnn_model/yolov4-tiny.cfg")

# %%
net
# Out:
# <dnn_Net 000001881754C190>

# %%
model=cv2.dnn_DetectionModel(net)
model.setInputParams(size=(320,320),scale=1/255)

# %%
cap= cv2.VideoCapture('abc.mp4')

# %%
# i=0
# while(cap.isOpened()):
#     ret, frame = cap.read()
#     cv2.imshow("frame",frame)
#     if ret == False:
#         break
#     i+=1
#     key=cv2.waitKey(1)
#     if key==27:
#         break
# cap.release()
# cv2.destroyAllWindows()

# %%
# cap=cv2.VideoCapture(0)
# while True:
#     ret,frame=cap.read()
#     cv2.imshow("frame",frame)
#     (class_ids, scores, bboxes) = model.detect(frame, confThreshold=0.03, nmsThreshold=0.004)
#     print("class_id",class_ids)
#     print("score",scores)
#     print("bdx",bboxes)
#     key=cv2.waitKey(1)
#     if key==27:
#         break
# cap.release()
# cv2.destroyAllWindows()

# %%
cap
# Out:
# <VideoCapture 0000018817383F10>

# %%
cap= cv2.VideoCapture('abc.mp4')
if (cap.isOpened()== False): 
    print("Error opening video stream or file")
while(cap.isOpened()):
    ret,frame=cap.read()
    img=cv2.resize(frame, (240,240))
    print(ret)
    dim=(128,128)
    if ret==False:
        break
    # print(frame)
    # print('Original Dimensions : ',frame.shape)
    #frame=cv2.resize(frame, dim, interpolation = cv2.INTER_AREA)
    cv2.imshow("frame",img)
    key = cv2.waitKey(5)
    if key==27:
        break
print()
cap.release()
cv2.destroyAllWindows()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# C:\Users\AYAZMH~1\AppData\Local\Temp/ipykernel_2712/3458505775.py in <module>
#       4 while(cap.isOpened()):
#       5     ret,frame=cap.read()
# ----> 6     img=cv2.resize(frame, (240,240))
#       7     print(ret)
#       8     dim=(128,128)
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
