# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path='/content/drive/MyDrive/YoloProjects/football_player'
print(os.listdir(path))
# Out:
# ['foot.png', 'football.mp4', 'train_data', 'yolov5', 'deep_sort', 'track.py', 'fooball.ipynb']

# %%
os.chdir('/content/drive/MyDrive/YoloProjects/football_player')

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo

# %%
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# /content/drive/MyDrive/YoloProjects/football_player/yolov5
#      |████████████████████████████████| 1.6 MB 41.9 MB/s
#      |████████████████████████████████| 41 kB 617 kB/s
#      |████████████████████████████████| 138 kB 66.6 MB/s
#      |████████████████████████████████| 67 kB 6.5 MB/s
#      |████████████████████████████████| 145 kB 77.1 MB/s
#      |████████████████████████████████| 178 kB 73.3 MB/s
#      |████████████████████████████████| 54 kB 3.0 MB/s
#      |████████████████████████████████| 62 kB 1.7 MB/s
# ...
# Setup complete. Using torch 1.12.1+cu113 (Tesla T4)

# %%
# !ls
# Out:
# benchmarks.py	 detect_track.py  __pycache__	    setup.cfg	    yolov5s.pt
# classify	 export.py	  README.md	    train.py
# CONTRIBUTING.md  hubconf.py	  requirements.txt  tutorial.ipynb
# data		 LICENSE	  runs		    utils
# detect.py	 models		  segment	    val.py

# %%
os.chdir('/content/drive/MyDrive/YoloProjects/football_player/yolov5')

# %%
# !ls
# Out:
# benchmarks.py	 detect_track.py  __pycache__	    setup.cfg	    yolov5s.pt
# classify	 export.py	  README.md	    train.py
# CONTRIBUTING.md  hubconf.py	  requirements.txt  tutorial.ipynb
# data		 LICENSE	  runs		    utils
# detect.py	 models		  segment	    val.py

# %%
#  !unzip /content/drive/MyDrive/Yolo/Dataset.zip -d /content/drive/MyDrive/MyYolo/custom_dat

# %%
# !python train.py --img 416 --batch 16 --epochs 5 --data data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 1054, done.
# remote: Counting objects: 100% (514/514), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 1054 (delta 457), reused 470 (delta 425), pack-reused 540
# Receiving objects: 100% (1054/1054), 347.02 KiB | 1.81 MiB/s, done.
# Command 'git fetch origin' timed out after 5 seconds
# ...

# %%
# !python train.py --img 416 --batch 16 --epochs 60 --data data/custom_data.yaml --weights runs/train/exp4/weights/best.pt --cache
# Out:
# train: weights=runs/train/exp4/weights/best.pt, cfg=, data=data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 41 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-198-gacff977 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !ls
# Out:
# benchmarks.py	 detect_track.py  __pycache__	    setup.cfg	    yolov5s.pt
# classify	 export.py	  README.md	    train.py
# CONTRIBUTING.md  hubconf.py	  requirements.txt  tutorial.ipynb
# data		 LICENSE	  runs		    utils
# detect.py	 models		  segment	    val.py

# %%
os.chdir('/content/drive/MyDrive/YoloProjects/football_player')

# %%
# !git clone https://github.com/nwojke/deep_sort.git
# Out:
# Cloning into 'deep_sort'...
# remote: Enumerating objects: 141, done.
# remote: Total 141 (delta 0), reused 0 (delta 0), pack-reused 141
# Receiving objects: 100% (141/141), 65.59 KiB | 3.45 MiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
# !ls
# Out:
# deep_sort  fooball.ipynb  football.mp4	foot.png  track.py  train_data	yolov5

# %%
# !python track.py --weights yolov5/yolov5s.pt --img 640  --source /content/drive/MyDrive/YoloProjects/football_player/football.mp4 --line-thickness 1
# Out:
# Traceback (most recent call last):
#   File "track.py", line 31, in <module>
#     from deep_sort.deep_sorting import DeepSort
#   File "/content/drive/MyDrive/YoloProjects/football_player/deep_sort/deep_sorting.py", line 4, in <module>
#     from .deep.feature_extractor import Extractor
# ModuleNotFoundError: No module named 'deep_sort.deep'

# %%
import torch
model = torch.hub.load('ultralytics/yolov5', 'custom', path='runs/train/exp5/weights/best.pt')  # local model
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-9-29 Python-3.7.14 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...

# %%
 # !python detect.py --weights runs/train/exp5/weights/best.pt --source /content/drive/MyDrive/YoloProjects/football_player/football.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2704/7701) /content/drive/MyDrive/YoloProjects/football_player/football.mp4: 384x640 1 Team1, 13 Team2s, 8.2ms
# video 1/1 (2705/7701) /content/drive/MyDrive/YoloProjects/football_player/football.mp4: 384x640 1 Team1, 13 Team2s, 7.8ms
# video 1/1 (2706/7701) /content/drive/MyDrive/YoloProjects/football_player/football.mp4: 384x640 1 Team1, 13 Team2s, 7.9ms
# video 1/1 (2707/7701) /content/drive/MyDrive/YoloProjects/football_player/football.mp4: 384x640 1 Team1, 13 Team2s, 7.7ms
# video 1/1 (2708/7701) /content/drive/MyDrive/YoloProjects/football_player/football.mp4: 384x640 1 Team1, 13 Team2s, 7.9ms
# video 1/1 (2709/7701) /content/drive/MyDrive/YoloProjects/football_player/football.mp4: 384x640 1 Team1, 13 Team2s, 7.7ms
# video 1/1 (2710/7701) /content/drive/MyDrive/YoloProjects/football_player/football.mp4: 384x640 1 Team1, 13 Team2s, 7.7ms
# ...
